# %% [markdown]
# ## Install packages

# %%
pip install -r requirements.txt
# Out:
# Collecting aiohappyeyeballs==2.4.3 (from -r requirements.txt (line 1))
#   Using cached aiohappyeyeballs-2.4.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiohttp==3.11.6 (from -r requirements.txt (line 2))
#   Downloading aiohttp-3.11.6-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting aiosignal==1.3.1 (from -r requirements.txt (line 3))
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting annotated-types==0.7.0 (from -r requirements.txt (line 4))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting anyio==4.6.2.post1 (from -r requirements.txt (line 5))
#   Using cached anyio-4.6.2.post1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: asttokens==2.4.1 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (2.4.1)
# Collecting attrs==24.2.0 (from -r requirements.txt (line 7))
#   Using cached attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: beautifulsoup4==4.12.3 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (4.12.3)
# Collecting bleach==6.2.0 (from -r requirements.txt (line 9))
#   Using cached bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting blinker==1.9.0 (from -r requirements.txt (line 10))
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting certifi==2024.8.30 (from -r requirements.txt (line 11))
#   Using cached certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting charset-normalizer==3.4.0 (from -r requirements.txt (line 12))
#   Downloading charset_normalizer-3.4.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (34 kB)
# Collecting click==8.1.7 (from -r requirements.txt (line 13))
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting dataclasses-json==0.6.7 (from -r requirements.txt (line 14))
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: decorator==5.1.1 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 15)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 16)) (0.7.1)
# Collecting Deprecated==1.2.15 (from -r requirements.txt (line 17))
#   Using cached Deprecated-1.2.15-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting dirtyjson==1.0.8 (from -r requirements.txt (line 18))
#   Using cached dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Collecting distro==1.9.0 (from -r requirements.txt (line 19))
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting executing==2.1.0 (from -r requirements.txt (line 20))
#   Using cached executing-2.1.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting faiss-cpu==1.9.0.post1 (from -r requirements.txt (line 21))
#   Downloading faiss_cpu-1.9.0.post1-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.4 kB)
# Collecting fastjsonschema==2.20.0 (from -r requirements.txt (line 22))
#   Using cached fastjsonschema-2.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting filelock==3.16.1 (from -r requirements.txt (line 23))
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting filetype==1.2.0 (from -r requirements.txt (line 24))
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting Flask==3.1.0 (from -r requirements.txt (line 25))
#   Using cached flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting frozenlist==1.5.0 (from -r requirements.txt (line 26))
#   Downloading frozenlist-1.5.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting fsspec==2024.10.0 (from -r requirements.txt (line 27))
#   Using cached fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting greenlet==3.1.1 (from -r requirements.txt (line 28))
#   Using cached greenlet-3.1.1-cp311-cp311-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Requirement already satisfied: h11==0.14.0 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 29)) (0.14.0)
# Collecting httpcore==1.0.7 (from -r requirements.txt (line 30))
#   Using cached httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting httpx==0.27.2 (from -r requirements.txt (line 31))
#   Using cached httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting huggingface-hub==0.26.2 (from -r requirements.txt (line 32))
#   Using cached huggingface_hub-0.26.2-py3-none-any.whl.metadata (13 kB)
# Collecting idna==3.10 (from -r requirements.txt (line 33))
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: ipython==8.29.0 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 34)) (8.29.0)
# Requirement already satisfied: itsdangerous==2.2.0 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 35)) (2.2.0)
# Collecting jedi==0.19.2 (from -r requirements.txt (line 36))
#   Using cached jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting Jinja2==3.1.4 (from -r requirements.txt (line 37))
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting jiter==0.7.1 (from -r requirements.txt (line 38))
#   Downloading jiter-0.7.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting joblib==1.4.2 (from -r requirements.txt (line 39))
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting jsonpatch==1.33 (from -r requirements.txt (line 40))
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting jsonpointer==3.0.0 (from -r requirements.txt (line 41))
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting jsonschema==4.23.0 (from -r requirements.txt (line 42))
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting jsonschema-specifications==2024.10.1 (from -r requirements.txt (line 43))
#   Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting jupyter_client==8.6.3 (from -r requirements.txt (line 44))
#   Using cached jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter_core==5.7.2 (from -r requirements.txt (line 45))
#   Using cached jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 46)) (0.3.0)
# Collecting langchain==0.3.7 (from -r requirements.txt (line 47))
#   Using cached langchain-0.3.7-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core==0.3.19 (from -r requirements.txt (line 48))
#   Using cached langchain_core-0.3.19-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters==0.3.2 (from -r requirements.txt (line 49))
#   Using cached langchain_text_splitters-0.3.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith==0.1.143 (from -r requirements.txt (line 50))
#   Using cached langsmith-0.1.143-py3-none-any.whl.metadata (13 kB)
# Collecting llama-cloud==0.1.5 (from -r requirements.txt (line 51))
#   Using cached llama_cloud-0.1.5-py3-none-any.whl.metadata (763 bytes)
# Collecting llama-index==0.12.0 (from -r requirements.txt (line 52))
#   Using cached llama_index-0.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting llama-index-agent-openai==0.4.0 (from -r requirements.txt (line 53))
#   Using cached llama_index_agent_openai-0.4.0-py3-none-any.whl.metadata (726 bytes)
# Collecting llama-index-cli==0.4.0 (from -r requirements.txt (line 54))
#   Using cached llama_index_cli-0.4.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-index-core==0.12.0 (from -r requirements.txt (line 55))
#   Using cached llama_index_core-0.12.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting llama-index-embeddings-openai==0.3.0 (from -r requirements.txt (line 56))
#   Using cached llama_index_embeddings_openai-0.3.0-py3-none-any.whl.metadata (684 bytes)
# Collecting llama-index-indices-managed-llama-cloud==0.6.2 (from -r requirements.txt (line 57))
#   Using cached llama_index_indices_managed_llama_cloud-0.6.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting llama-index-legacy==0.9.48.post4 (from -r requirements.txt (line 58))
#   Using cached llama_index_legacy-0.9.48.post4-py3-none-any.whl.metadata (8.5 kB)
# Collecting llama-index-llms-openai==0.3.0 (from -r requirements.txt (line 59))
#   Using cached llama_index_llms_openai-0.3.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting llama-index-multi-modal-llms-openai==0.3.0 (from -r requirements.txt (line 60))
#   Using cached llama_index_multi_modal_llms_openai-0.3.0-py3-none-any.whl.metadata (726 bytes)
# Collecting llama-index-program-openai==0.3.0 (from -r requirements.txt (line 61))
#   Using cached llama_index_program_openai-0.3.0-py3-none-any.whl.metadata (764 bytes)
# Collecting llama-index-question-gen-openai==0.3.0 (from -r requirements.txt (line 62))
#   Using cached llama_index_question_gen_openai-0.3.0-py3-none-any.whl.metadata (783 bytes)
# Collecting llama-index-readers-file==0.4.0 (from -r requirements.txt (line 63))
#   Using cached llama_index_readers_file-0.4.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-readers-llama-parse==0.4.0 (from -r requirements.txt (line 64))
#   Using cached llama_index_readers_llama_parse-0.4.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting llama-parse==0.5.14 (from -r requirements.txt (line 65))
#   Using cached llama_parse-0.5.14-py3-none-any.whl.metadata (6.9 kB)
# Collecting MarkupSafe==3.0.2 (from -r requirements.txt (line 66))
#   Downloading MarkupSafe-3.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting marshmallow==3.23.1 (from -r requirements.txt (line 67))
#   Using cached marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting matplotlib-inline==0.1.7 (from -r requirements.txt (line 68))
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: mistune==3.0.2 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 69)) (3.0.2)
# Collecting mpmath==1.3.0 (from -r requirements.txt (line 70))
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting multidict==6.1.0 (from -r requirements.txt (line 71))
#   Downloading multidict-6.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.0 kB)
# Requirement already satisfied: mypy-extensions==1.0.0 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 72)) (1.0.0)
# Collecting nbclient==0.10.0 (from -r requirements.txt (line 73))
#   Using cached nbclient-0.10.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting nbconvert==7.16.4 (from -r requirements.txt (line 74))
#   Using cached nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# Collecting nbformat==5.10.4 (from -r requirements.txt (line 75))
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: nest-asyncio==1.6.0 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 76)) (1.6.0)
# Collecting networkx==3.4.2 (from -r requirements.txt (line 77))
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting nltk==3.9.1 (from -r requirements.txt (line 78))
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting numpy==1.26.4 (from -r requirements.txt (line 79))
#   Downloading numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (114 kB)
# Collecting openai==1.54.5 (from -r requirements.txt (line 80))
#   Using cached openai-1.54.5-py3-none-any.whl.metadata (24 kB)
# Collecting orjson==3.10.11 (from -r requirements.txt (line 81))
#   Using cached orjson-3.10.11-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (50 kB)
# Collecting packaging==24.2 (from -r requirements.txt (line 82))
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pandas==2.2.3 (from -r requirements.txt (line 83))
#   Downloading pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (89 kB)
# Requirement already satisfied: pandocfilters==1.5.1 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 84)) (1.5.1)
# Collecting parso==0.8.4 (from -r requirements.txt (line 85))
#   Using cached parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: pexpect==4.9.0 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 86)) (4.9.0)
# Collecting pillow==11.0.0 (from -r requirements.txt (line 87))
#   Downloading pillow-11.0.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting platformdirs==4.3.6 (from -r requirements.txt (line 88))
#   Using cached platformdirs-4.3.6-py3-none-any.whl.metadata (11 kB)
# Collecting prompt_toolkit==3.0.48 (from -r requirements.txt (line 89))
#   Using cached prompt_toolkit-3.0.48-py3-none-any.whl.metadata (6.4 kB)
# Collecting propcache==0.2.0 (from -r requirements.txt (line 90))
#   Downloading propcache-0.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Requirement already satisfied: ptyprocess==0.7.0 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 91)) (0.7.0)
# Collecting pure_eval==0.2.3 (from -r requirements.txt (line 92))
#   Using cached pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting pydantic==2.9.2 (from -r requirements.txt (line 93))
#   Using cached pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Collecting pydantic_core==2.23.4 (from -r requirements.txt (line 94))
#   Downloading pydantic_core-2.23.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting Pygments==2.18.0 (from -r requirements.txt (line 95))
#   Using cached pygments-2.18.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pypdf==5.1.0 (from -r requirements.txt (line 96))
#   Using cached pypdf-5.1.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting python-dateutil==2.9.0.post0 (from -r requirements.txt (line 97))
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz==2024.2 (from -r requirements.txt (line 98))
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting PyYAML==6.0.2 (from -r requirements.txt (line 99))
#   Downloading PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting pyzmq==26.2.0 (from -r requirements.txt (line 100))
#   Using cached pyzmq-26.2.0-cp311-cp311-macosx_10_15_universal2.whl.metadata (6.2 kB)
# Collecting referencing==0.35.1 (from -r requirements.txt (line 101))
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting regex==2024.11.6 (from -r requirements.txt (line 102))
#   Downloading regex-2024.11.6-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting requests==2.32.3 (from -r requirements.txt (line 103))
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: requests-toolbelt==1.0.0 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 104)) (1.0.0)
# Collecting rpds-py==0.21.0 (from -r requirements.txt (line 105))
#   Downloading rpds_py-0.21.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting safetensors==0.4.5 (from -r requirements.txt (line 106))
#   Downloading safetensors-0.4.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting scikit-learn==1.5.2 (from -r requirements.txt (line 107))
#   Downloading scikit_learn-1.5.2-cp311-cp311-macosx_12_0_arm64.whl.metadata (13 kB)
# Collecting scipy==1.14.1 (from -r requirements.txt (line 108))
#   Downloading scipy-1.14.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (60 kB)
# Collecting sentence-transformers==3.3.1 (from -r requirements.txt (line 109))
#   Using cached sentence_transformers-3.3.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: six==1.16.0 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 110)) (1.16.0)
# Collecting sniffio==1.3.1 (from -r requirements.txt (line 111))
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting soupsieve==2.6 (from -r requirements.txt (line 112))
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting SQLAlchemy==2.0.36 (from -r requirements.txt (line 113))
#   Downloading SQLAlchemy-2.0.36-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Requirement already satisfied: stack-data==0.6.3 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 114)) (0.6.3)
# Collecting striprtf==0.0.26 (from -r requirements.txt (line 115))
#   Using cached striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting sympy==1.13.3 (from -r requirements.txt (line 116))
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting tenacity==8.5.0 (from -r requirements.txt (line 117))
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: threadpoolctl==3.5.0 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 118)) (3.5.0)
# Collecting tiktoken==0.8.0 (from -r requirements.txt (line 119))
#   Downloading tiktoken-0.8.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting tinycss2==1.4.0 (from -r requirements.txt (line 120))
#   Using cached tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting tokenizers==0.20.3 (from -r requirements.txt (line 121))
#   Downloading tokenizers-0.20.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting torch==2.2.2 (from -r requirements.txt (line 122))
#   Downloading torch-2.2.2-cp311-none-macosx_11_0_arm64.whl.metadata (25 kB)
# Collecting tornado==6.4.1 (from -r requirements.txt (line 123))
#   Downloading tornado-6.4.1-cp38-abi3-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting tqdm==4.67.0 (from -r requirements.txt (line 124))
#   Using cached tqdm-4.67.0-py3-none-any.whl.metadata (57 kB)
# Collecting traitlets==5.14.3 (from -r requirements.txt (line 125))
#   Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting transformers==4.46.3 (from -r requirements.txt (line 126))
#   Using cached transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
# Collecting typing-inspect==0.9.0 (from -r requirements.txt (line 127))
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: typing_extensions==4.12.2 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 128)) (4.12.2)
# Collecting tzdata==2024.2 (from -r requirements.txt (line 129))
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting urllib3==2.2.3 (from -r requirements.txt (line 130))
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: wcwidth==0.2.13 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 131)) (0.2.13)
# Requirement already satisfied: webencodings==0.5.1 in /Users/Felipe_Vianna/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from -r requirements.txt (line 132)) (0.5.1)
# Collecting Werkzeug==3.1.3 (from -r requirements.txt (line 133))
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting wrapt==1.16.0 (from -r requirements.txt (line 134))
#   Downloading wrapt-1.16.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting yarl==1.17.2 (from -r requirements.txt (line 135))
#   Downloading yarl-1.17.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (66 kB)
# Using cached aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Downloading aiohttp-3.11.6-cp311-cp311-macosx_11_0_arm64.whl (454 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached anyio-4.6.2.post1-py3-none-any.whl (90 kB)
# Using cached attrs-24.2.0-py3-none-any.whl (63 kB)
# Using cached bleach-6.2.0-py3-none-any.whl (163 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached certifi-2024.8.30-py3-none-any.whl (167 kB)
# Downloading charset_normalizer-3.4.0-cp311-cp311-macosx_11_0_arm64.whl (118 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Using cached dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached executing-2.1.0-py2.py3-none-any.whl (25 kB)
# Downloading faiss_cpu-1.9.0.post1-cp311-cp311-macosx_11_0_arm64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 7.1 MB/s eta 0:00:000:00:010:00:01
# Using cached fastjsonschema-2.20.0-py3-none-any.whl (23 kB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached flask-3.1.0-py3-none-any.whl (102 kB)
# Downloading frozenlist-1.5.0-cp311-cp311-macosx_11_0_arm64.whl (52 kB)
# Using cached fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Using cached greenlet-3.1.1-cp311-cp311-macosx_11_0_universal2.whl (272 kB)
# Using cached httpcore-1.0.7-py3-none-any.whl (78 kB)
# Using cached httpx-0.27.2-py3-none-any.whl (76 kB)
# Using cached huggingface_hub-0.26.2-py3-none-any.whl (447 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Downloading jiter-0.7.1-cp311-cp311-macosx_11_0_arm64.whl (303 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Using cached jupyter_client-8.6.3-py3-none-any.whl (106 kB)
# Using cached jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Using cached langchain-0.3.7-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.19-py3-none-any.whl (409 kB)
# Using cached langchain_text_splitters-0.3.2-py3-none-any.whl (25 kB)
# Using cached langsmith-0.1.143-py3-none-any.whl (306 kB)
# Using cached llama_cloud-0.1.5-py3-none-any.whl (188 kB)
# Using cached llama_index-0.12.0-py3-none-any.whl (6.8 kB)
# Using cached llama_index_agent_openai-0.4.0-py3-none-any.whl (13 kB)
# Using cached llama_index_cli-0.4.0-py3-none-any.whl (27 kB)
# Using cached llama_index_core-0.12.0-py3-none-any.whl (1.6 MB)
# Using cached llama_index_embeddings_openai-0.3.0-py3-none-any.whl (6.1 kB)
# Using cached llama_index_indices_managed_llama_cloud-0.6.2-py3-none-any.whl (11 kB)
# Using cached llama_index_legacy-0.9.48.post4-py3-none-any.whl (1.2 MB)
# Using cached llama_index_llms_openai-0.3.0-py3-none-any.whl (13 kB)
# Using cached llama_index_multi_modal_llms_openai-0.3.0-py3-none-any.whl (5.9 kB)
# Using cached llama_index_program_openai-0.3.0-py3-none-any.whl (5.3 kB)
# Using cached llama_index_question_gen_openai-0.3.0-py3-none-any.whl (2.9 kB)
# Using cached llama_index_readers_file-0.4.0-py3-none-any.whl (38 kB)
# Using cached llama_index_readers_llama_parse-0.4.0-py3-none-any.whl (2.5 kB)
# Using cached llama_parse-0.5.14-py3-none-any.whl (13 kB)
# Downloading MarkupSafe-3.0.2-cp311-cp311-macosx_11_0_arm64.whl (12 kB)
# Using cached marshmallow-3.23.1-py3-none-any.whl (49 kB)
# Using cached matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading multidict-6.1.0-cp311-cp311-macosx_11_0_arm64.whl (29 kB)
# Using cached nbclient-0.10.0-py3-none-any.whl (25 kB)
# Using cached nbconvert-7.16.4-py3-none-any.whl (257 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Downloading numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 7.2 MB/s eta 0:00:007.4 MB/s eta 0:00:01
# Using cached openai-1.54.5-py3-none-any.whl (389 kB)
# Using cached orjson-3.10.11-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (266 kB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Downloading pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 7.3 MB/s eta 0:00:007.4 MB/s eta 0:00:01
# Using cached parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Downloading pillow-11.0.0-cp311-cp311-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 6.7 MB/s eta 0:00:007.4 MB/s eta 0:00:01
# Using cached platformdirs-4.3.6-py3-none-any.whl (18 kB)
# Using cached prompt_toolkit-3.0.48-py3-none-any.whl (386 kB)
# Downloading propcache-0.2.0-cp311-cp311-macosx_11_0_arm64.whl (45 kB)
# Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Using cached pydantic-2.9.2-py3-none-any.whl (434 kB)
# Downloading pydantic_core-2.23.4-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 6.7 MB/s eta 0:00:007.4 MB/s eta 0:00:01
# Using cached pygments-2.18.0-py3-none-any.whl (1.2 MB)
# Using cached pypdf-5.1.0-py3-none-any.whl (297 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl (172 kB)
# Using cached pyzmq-26.2.0-cp311-cp311-macosx_10_15_universal2.whl (1.3 MB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading regex-2024.11.6-cp311-cp311-macosx_11_0_arm64.whl (284 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading rpds_py-0.21.0-cp311-cp311-macosx_11_0_arm64.whl (318 kB)
# Downloading safetensors-0.4.5-cp311-cp311-macosx_11_0_arm64.whl (381 kB)
# Downloading scikit_learn-1.5.2-cp311-cp311-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 7.3 MB/s eta 0:00:000:00:0136m0:00:01:01
# Downloading scipy-1.14.1-cp311-cp311-macosx_14_0_arm64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 7.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Using cached sentence_transformers-3.3.1-py3-none-any.whl (268 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Downloading SQLAlchemy-2.0.36-cp311-cp311-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 6.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# Using cached striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Using cached sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Using cached tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading tiktoken-0.8.0-cp311-cp311-macosx_11_0_arm64.whl (982 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 982.4/982.4 kB 6.8 MB/s eta 0:00:00
# Using cached tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Downloading tokenizers-0.20.3-cp311-cp311-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 6.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading torch-2.2.2-cp311-none-macosx_11_0_arm64.whl (59.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 MB 6.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading tornado-6.4.1-cp38-abi3-macosx_10_9_universal2.whl (435 kB)
# Using cached tqdm-4.67.0-py3-none-any.whl (78 kB)
# Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Using cached transformers-4.46.3-py3-none-any.whl (10.0 MB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading wrapt-1.16.0-cp311-cp311-macosx_11_0_arm64.whl (38 kB)
# Downloading yarl-1.17.2-cp311-cp311-macosx_11_0_arm64.whl (91 kB)
# Installing collected packages: striprtf, pytz, pure_eval, mpmath, filetype, fastjsonschema, dirtyjson, wrapt, urllib3, tzdata, typing-inspect, traitlets, tqdm, tornado, tinycss2, tenacity, sympy, SQLAlchemy, soupsieve, sniffio, safetensors, rpds-py, regex, pyzmq, PyYAML, python-dateutil, pypdf, Pygments, pydantic_core, propcache, prompt_toolkit, platformdirs, pillow, parso, packaging, orjson, numpy, networkx, multidict, MarkupSafe, jsonpointer, joblib, jiter, idna, greenlet, fsspec, frozenlist, filelock, executing, distro, click, charset-normalizer, certifi, blinker, bleach, attrs, annotated-types, aiohappyeyeballs, yarl, Werkzeug, scipy, requests, referencing, pydantic, pandas, nltk, matplotlib-inline, marshmallow, jupyter_core, jsonpatch, Jinja2, jedi, httpcore, faiss-cpu, Deprecated, anyio, aiosignal, torch, tiktoken, scikit-learn, jupyter_client, jsonschema-specifications, huggingface-hub, httpx, Flask, dataclasses-json, aiohttp, tokenizers, openai, llama-index-core, llama-cloud, langsmith, jsonschema, transformers, nbformat, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-legacy, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, langchain-core, sentence-transformers, nbclient, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, langchain-text-splitters, nbconvert, llama-index-program-openai, langchain, llama-index-question-gen-openai, llama-index
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2023.4
#     Uninstalling pytz-2023.4:
#       Successfully uninstalled pytz-2023.4
#   Attempting uninstall: pure_eval
#     Found existing installation: pure-eval 0.2.2
#     Uninstalling pure-eval-0.2.2:
#       Successfully uninstalled pure-eval-0.2.2
#   Attempting uninstall: fastjsonschema
#     Found existing installation: fastjsonschema 2.19.1
#     Uninstalling fastjsonschema-2.19.1:
#       Successfully uninstalled fastjsonschema-2.19.1
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.1
#     Uninstalling wrapt-1.14.1:
#       Successfully uninstalled wrapt-1.14.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.1.0
#     Uninstalling urllib3-2.1.0:
#       Successfully uninstalled urllib3-2.1.0
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2023.4
#     Uninstalling tzdata-2023.4:
#       Successfully uninstalled tzdata-2023.4
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.14.1
#     Uninstalling traitlets-5.14.1:
#       Successfully uninstalled traitlets-5.14.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.4
#     Uninstalling tornado-6.4:
#       Successfully uninstalled tornado-6.4
#   Attempting uninstall: tinycss2
#     Found existing installation: tinycss2 1.2.1
#     Uninstalling tinycss2-1.2.1:
#       Successfully uninstalled tinycss2-1.2.1
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.2.3
#     Uninstalling tenacity-8.2.3:
#       Successfully uninstalled tenacity-8.2.3
#   Attempting uninstall: soupsieve
#     Found existing installation: soupsieve 2.5
#     Uninstalling soupsieve-2.5:
#       Successfully uninstalled soupsieve-2.5
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.3.0
#     Uninstalling sniffio-1.3.0:
#       Successfully uninstalled sniffio-1.3.0
#   Attempting uninstall: rpds-py
#     Found existing installation: rpds-py 0.18.0
#     Uninstalling rpds-py-0.18.0:
#       Successfully uninstalled rpds-py-0.18.0
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 25.1.2
#     Uninstalling pyzmq-25.1.2:
#       Successfully uninstalled pyzmq-25.1.2
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: Pygments
#     Found existing installation: Pygments 2.17.2
#     Uninstalling Pygments-2.17.2:
#       Successfully uninstalled Pygments-2.17.2
#   Attempting uninstall: pydantic_core
#     Found existing installation: pydantic_core 2.14.6
#     Uninstalling pydantic_core-2.14.6:
#       Successfully uninstalled pydantic_core-2.14.6
#   Attempting uninstall: prompt_toolkit
#     Found existing installation: prompt-toolkit 3.0.43
#     Uninstalling prompt-toolkit-3.0.43:
#       Successfully uninstalled prompt-toolkit-3.0.43
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 3.11.0
#     Uninstalling platformdirs-3.11.0:
#       Successfully uninstalled platformdirs-3.11.0
#   Attempting uninstall: pillow
#     Found existing installation: pillow 10.2.0
#     Uninstalling pillow-10.2.0:
#       Successfully uninstalled pillow-10.2.0
#   Attempting uninstall: parso
#     Found existing installation: parso 0.8.3
#     Uninstalling parso-0.8.3:
#       Successfully uninstalled parso-0.8.3
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.2.1
#     Uninstalling networkx-3.2.1:
#       Successfully uninstalled networkx-3.2.1
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.5
#     Uninstalling MarkupSafe-2.1.5:
#       Successfully uninstalled MarkupSafe-2.1.5
#   Attempting uninstall: jsonpointer
#     Found existing installation: jsonpointer 2.4
#     Uninstalling jsonpointer-2.4:
#       Successfully uninstalled jsonpointer-2.4
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.3.2
#     Uninstalling joblib-1.3.2:
#       Successfully uninstalled joblib-1.3.2
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.13.1
#     Uninstalling filelock-3.13.1:
#       Successfully uninstalled filelock-3.13.1
#   Attempting uninstall: executing
#     Found existing installation: executing 2.0.1
#     Uninstalling executing-2.0.1:
#       Successfully uninstalled executing-2.0.1
#   Attempting uninstall: click
#     Found existing installation: click 8.0.4
#     Uninstalling click-8.0.4:
#       Successfully uninstalled click-8.0.4
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.2
#     Uninstalling charset-normalizer-3.3.2:
#       Successfully uninstalled charset-normalizer-3.3.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.11.17
#     Uninstalling certifi-2023.11.17:
#       Successfully uninstalled certifi-2023.11.17
#   Attempting uninstall: blinker
#     Found existing installation: blinker 1.7.0
#     Uninstalling blinker-1.7.0:
#       Successfully uninstalled blinker-1.7.0
#   Attempting uninstall: bleach
#     Found existing installation: bleach 6.1.0
#     Uninstalling bleach-6.1.0:
#       Successfully uninstalled bleach-6.1.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.2.0
#     Uninstalling attrs-23.2.0:
#       Successfully uninstalled attrs-23.2.0
#   Attempting uninstall: annotated-types
#     Found existing installation: annotated-types 0.6.0
#     Uninstalling annotated-types-0.6.0:
#       Successfully uninstalled annotated-types-0.6.0
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 3.0.2
#     Uninstalling Werkzeug-3.0.2:
#       Successfully uninstalled Werkzeug-3.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.12.0
#     Uninstalling scipy-1.12.0:
#       Successfully uninstalled scipy-1.12.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: referencing
#     Found existing installation: referencing 0.33.0
#     Uninstalling referencing-0.33.0:
#       Successfully uninstalled referencing-0.33.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.3
#     Uninstalling pydantic-2.5.3:
#       Successfully uninstalled pydantic-2.5.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: matplotlib-inline
#     Found existing installation: matplotlib-inline 0.1.6
#     Uninstalling matplotlib-inline-0.1.6:
#       Successfully uninstalled matplotlib-inline-0.1.6
#   Attempting uninstall: jupyter_core
#     Found existing installation: jupyter_core 5.7.1
#     Uninstalling jupyter_core-5.7.1:
#       Successfully uninstalled jupyter_core-5.7.1
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 3.1.3
#     Uninstalling Jinja2-3.1.3:
#       Successfully uninstalled Jinja2-3.1.3
#   Attempting uninstall: jedi
#     Found existing installation: jedi 0.19.1
#     Uninstalling jedi-0.19.1:
#       Successfully uninstalled jedi-0.19.1
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.4
#     Uninstalling httpcore-1.0.4:
#       Successfully uninstalled httpcore-1.0.4
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.2.0
#     Uninstalling anyio-4.2.0:
#       Successfully uninstalled anyio-4.2.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.2
#     Uninstalling scikit-learn-1.3.2:
#       Successfully uninstalled scikit-learn-1.3.2
#   Attempting uninstall: jupyter_client
#     Found existing installation: jupyter_client 8.6.0
#     Uninstalling jupyter_client-8.6.0:
#       Successfully uninstalled jupyter_client-8.6.0
#   Attempting uninstall: jsonschema-specifications
#     Found existing installation: jsonschema-specifications 2023.12.1
#     Uninstalling jsonschema-specifications-2023.12.1:
#       Successfully uninstalled jsonschema-specifications-2023.12.1
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.0
#     Uninstalling httpx-0.27.0:
#       Successfully uninstalled httpx-0.27.0
#   Attempting uninstall: Flask
#     Found existing installation: Flask 2.2.5
#     Uninstalling Flask-2.2.5:
#       Successfully uninstalled Flask-2.2.5
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.21.1
#     Uninstalling jsonschema-4.21.1:
#       Successfully uninstalled jsonschema-4.21.1
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.9.2
#     Uninstalling nbformat-5.9.2:
#       Successfully uninstalled nbformat-5.9.2
#   Attempting uninstall: nbclient
#     Found existing installation: nbclient 0.9.0
#     Uninstalling nbclient-0.9.0:
#       Successfully uninstalled nbclient-0.9.0
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 7.16.1
#     Uninstalling nbconvert-7.16.1:
#       Successfully uninstalled nbconvert-7.16.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# poetry 1.7.1 requires platformdirs<4.0.0,>=3.0.0, but you have platformdirs 4.3.6 which is incompatible.
# ydata-profiling 4.10.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.
# optimus-batch-analytics-app 0.9.0 requires click<8.1.0, but you have click 8.1.7 which is incompatible.
# optimus-batch-analytics-app 0.9.0 requires numpy<1.24,>=1.21, but you have numpy 1.26.4 which is incompatible.
# optimus-batch-analytics-app 0.9.0 requires numpy<1.24,~=1.21, but you have numpy 1.26.4 which is incompatible.
# optimus-batch-analytics-app 0.9.0 requires pandas<2.0,>=1.5.3, but you have pandas 2.2.3 which is incompatible.
# optimus-batch-analytics-app 0.9.0 requires scikit-learn~=1.3.0, but you have scikit-learn 1.5.2 which is incompatible.
# optimus-batch-analytics-app 0.9.0 requires scipy<1.13.0, but you have scipy 1.14.1 which is incompatible.
# tensorflow 2.15.1 requires wrapt<1.15,>=1.11.0, but you have wrapt 1.16.0 which is incompatible.
# pipreqs 0.5.0 requires ipython==8.12.3, but you have ipython 8.29.0 which is incompatible.
# dash 2.16.1 requires Flask<3.1,>=1.0.4, but you have flask 3.1.0 which is incompatible.
# dash 2.16.1 requires Werkzeug<3.1, but you have werkzeug 3.1.3 which is incompatible.
# Successfully installed Deprecated-1.2.15 Flask-3.1.0 Jinja2-3.1.4 MarkupSafe-3.0.2 PyYAML-6.0.2 Pygments-2.18.0 SQLAlchemy-2.0.36 Werkzeug-3.1.3 aiohappyeyeballs-2.4.3 aiohttp-3.11.6 aiosignal-1.3.1 annotated-types-0.7.0 anyio-4.6.2.post1 attrs-24.2.0 bleach-6.2.0 blinker-1.9.0 certifi-2024.8.30 charset-normalizer-3.4.0 click-8.1.7 dataclasses-json-0.6.7 dirtyjson-1.0.8 distro-1.9.0 executing-2.1.0 faiss-cpu-1.9.0.post1 fastjsonschema-2.20.0 filelock-3.16.1 filetype-1.2.0 frozenlist-1.5.0 fsspec-2024.10.0 greenlet-3.1.1 httpcore-1.0.7 httpx-0.27.2 huggingface-hub-0.26.2 idna-3.10 jedi-0.19.2 jiter-0.7.1 joblib-1.4.2 jsonpatch-1.33 jsonpointer-3.0.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 jupyter_client-8.6.3 jupyter_core-5.7.2 langchain-0.3.7 langchain-core-0.3.19 langchain-text-splitters-0.3.2 langsmith-0.1.143 llama-cloud-0.1.5 llama-index-0.12.0 llama-index-agent-openai-0.4.0 llama-index-cli-0.4.0 llama-index-core-0.12.0 llama-index-embeddings-openai-0.3.0 llama-index-indices-managed-llama-cloud-0.6.2 llama-index-legacy-0.9.48.post4 llama-index-llms-openai-0.3.0 llama-index-multi-modal-llms-openai-0.3.0 llama-index-program-openai-0.3.0 llama-index-question-gen-openai-0.3.0 llama-index-readers-file-0.4.0 llama-index-readers-llama-parse-0.4.0 llama-parse-0.5.14 marshmallow-3.23.1 matplotlib-inline-0.1.7 mpmath-1.3.0 multidict-6.1.0 nbclient-0.10.0 nbconvert-7.16.4 nbformat-5.10.4 networkx-3.4.2 nltk-3.9.1 numpy-1.26.4 openai-1.54.5 orjson-3.10.11 packaging-24.2 pandas-2.2.3 parso-0.8.4 pillow-11.0.0 platformdirs-4.3.6 prompt_toolkit-3.0.48 propcache-0.2.0 pure_eval-0.2.3 pydantic-2.9.2 pydantic_core-2.23.4 pypdf-5.1.0 python-dateutil-2.9.0.post0 pytz-2024.2 pyzmq-26.2.0 referencing-0.35.1 regex-2024.11.6 requests-2.32.3 rpds-py-0.21.0 safetensors-0.4.5 scikit-learn-1.5.2 scipy-1.14.1 sentence-transformers-3.3.1 sniffio-1.3.1 soupsieve-2.6 striprtf-0.0.26 sympy-1.13.3 tenacity-8.5.0 tiktoken-0.8.0 tinycss2-1.4.0 tokenizers-0.20.3 torch-2.2.2 tornado-6.4.1 tqdm-4.67.0 traitlets-5.14.3 transformers-4.46.3 typing-inspect-0.9.0 tzdata-2024.2 urllib3-2.2.3 wrapt-1.16.0 yarl-1.17.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Set environment
# ensure you have a .env file with the variables:
#
# ```
# OPENAI_API_KEY="your openai key"
# OPENAI_API_BASE="your openai URL"
# ```

# %%
# !export $(grep -v '^#' .env | xargs)

# %% [markdown]
# ## Test connectivity

# %%
from src.llama_index_test import test_llamaindex

# %%
test_llamaindex(query="Who's Shakespeare?")
# Out:
# Response: Shakespeare is a poetic and eloquent wordsmith, whose deep understanding of human nature shines through his dialogue.

# %%
test_llamaindex(query="Who's Deadpool?")
# Out:
# Response: Deadpool is a witty, sarcastic anti-hero.
